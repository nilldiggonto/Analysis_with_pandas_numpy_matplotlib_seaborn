# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('car_sales_dt.csv')

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
data['Wheels'] = 4

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels
# 0  Toyota  White         150043      4   400000       4
# 1   Honda    Red          87899      4   500000       4
# 2  Toyota   Blue          32549      3   700000       4
# 3     BMW  Black          11179      5  2200000       4
# 4  Nissan  White         213095      4   350000       4
# 5  Toyota  Green          99213      4   450000       4
# 6   Honda   Blue          45698      4   750000       4
# 7   Honda   Blue          54738      4   700000       4
# 8  Toyota  White          60000      4   625000       4
# 9  Nissan  White          31600      4   970000       4

# %%
data['Safety Check'] =True

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True

# %%
data['Fuel (PKM)'] =np.random.randint(10,15,10)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
#
#    Fuel (PKM)
# 0          11
# 1          10
# 2          11
# 3          14
# 4          11
# 5          12
# 6          10
# 7          10
# 8          14
# 9          11

# %%
data['Total Fuel'] = (data['Odometer (KM)']/100) * data['Fuel (PKM)']

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    16504.73
# 1          10     8789.90
# 2          11     3580.39
# 3          14     1565.06
# 4          11    23440.45
# 5          12    11905.56
# ...

# %%
data['Discount'] = np.linspace(1,5,10)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
#
#    Fuel (PKM)  Total Fuel  Discount
# 0          11    16504.73  1.000000
# 1          10     8789.90  1.444444
# 2          11     3580.39  1.888889
# 3          14     1565.06  2.333333
# ...

# %%
#######################################

# %%
#drop column

# %%
data.drop('Discount',axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    16504.73
# 1          10     8789.90
# 2          11     3580.39
# 3          14     1565.06
# 4          11    23440.45
# 5          12    11905.56
# ...

# %%
data = data.drop('Discount',axis=1)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    16504.73
# 1          10     8789.90
# 2          11     3580.39
# 3          14     1565.06
# 4          11    23440.45
# 5          12    11905.56
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int64
#  5   Wheels         10 non-null     int64
#  6   Safety Check   10 non-null     bool
#  7   Fuel (PKM)     10 non-null     int32
#  8   Total Fuel     10 non-null     float64
# dtypes: bool(1), float64(1), int32(1), int64(4), object(2)
# memory usage: 738.0+ bytes

# %%
#########################################################

# %%
#shuffle index

# %%
data.sample(frac=0.5) #50% of data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Toyota  White         150043      4   400000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    16504.73
# 8          14     8400.00
# 3          14     1565.06
# 7          10     5473.80
# 6          10     4569.80

# %%
shuffle_data = data.sample(frac=1)

# %%
shuffle_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 0  Toyota  White         150043      4   400000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
#
#    Fuel (PKM)  Total Fuel
# 4          11    23440.45
# 5          12    11905.56
# 3          14     1565.06
# 7          10     5473.80
# 2          11     3580.39
# 8          14     8400.00
# ...

# %%
shuffle_data.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0      4  Nissan  White         213095      4   350000       4          True
# 1      5  Toyota  Green          99213      4   450000       4          True
# 2      3     BMW  Black          11179      5  2200000       4          True
# 3      7   Honda   Blue          54738      4   700000       4          True
# 4      2  Toyota   Blue          32549      3   700000       4          True
# 5      8  Toyota  White          60000      4   625000       4          True
# 6      9  Nissan  White          31600      4   970000       4          True
# 7      1   Honda    Red          87899      4   500000       4          True
# 8      0  Toyota  White         150043      4   400000       4          True
# 9      6   Honda   Blue          45698      4   750000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    23440.45
# 1          12    11905.56
# 2          14     1565.06
# ...

# %%
shuffle_data.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 0  Nissan  White         213095      4   350000       4          True
# 1  Toyota  Green          99213      4   450000       4          True
# 2     BMW  Black          11179      5  2200000       4          True
# 3   Honda   Blue          54738      4   700000       4          True
# 4  Toyota   Blue          32549      3   700000       4          True
# 5  Toyota  White          60000      4   625000       4          True
# 6  Nissan  White          31600      4   970000       4          True
# 7   Honda    Red          87899      4   500000       4          True
# 8  Toyota  White         150043      4   400000       4          True
# 9   Honda   Blue          45698      4   750000       4          True
#
#    Fuel (PKM)  Total Fuel
# 0          11    23440.45
# 1          12    11905.56
# 2          14     1565.06
# 3          10     5473.80
# 4          11     3580.39
# 5          14     8400.00
# ...

# %%
#apply function

# %%
shuffle_data['Total Fuel'] = data['Total Fuel'].apply(lambda x:x-100)

# %%
shuffle_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Wheels  Safety Check  \
# 4  Nissan  White         213095      4   350000       4          True
# 5  Toyota  Green          99213      4   450000       4          True
# 3     BMW  Black          11179      5  2200000       4          True
# 7   Honda   Blue          54738      4   700000       4          True
# 2  Toyota   Blue          32549      3   700000       4          True
# 8  Toyota  White          60000      4   625000       4          True
# 9  Nissan  White          31600      4   970000       4          True
# 1   Honda    Red          87899      4   500000       4          True
# 0  Toyota  White         150043      4   400000       4          True
# 6   Honda   Blue          45698      4   750000       4          True
#
#    Fuel (PKM)  Total Fuel
# 4          11    23240.45
# 5          12    11705.56
# 3          14     1365.06
# 7          10     5273.80
# 2          11     3380.39
# 8          14     8200.00
# ...
